# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import RELLISUR_DataLoader as rel
import srmodels as srm
import utils as u

# %%
device = 'cuda'

# %%
batch_size = 4

train_ds, val_ds, test_ds = rel.get_SR_datasets(1,2)
train_dl, val_dl, test_dl = rel.get_SR_dataloaders(train_ds, val_ds, test_ds, batch_size)

# %%
model = srm.SimpleSR().to(device)

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001) 

u.training_loop(model, criterion, optimizer, 20, train_dl, device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 criterion = nn.MSELoss()
#       2 optimizer = optim.Adam(model.parameters(), lr=0.001)
# ----> 4 u.training_loop(model, criterion, optimizer, 20, train_dl, device)
#
# File ~/Documents/vc/SuperResLight/src/SR/utils.py:28, in training_loop(model, criterion, optimizer, n_epochs, train_dl, device)
#      24     running_loss += loss.item() * lr_images.size(0)
#      26 epoch_loss = running_loss / len(train_dl.dataset)
# ---> 28 print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.6f}")
#
# NameError: name 'num_epochs' is not defined

# %%
u.visualize_results(model, val_dl, device, num_samples=3)
